# %%
import pandas as pd
from collections import Counter

import re

from sqlalchemy import create_engine
import psycopg2

from config import db_password

# %%
# Import health dataset
health_data = pd.read_csv('raw_data/Health_Data.csv')
health_data.head()
# Out:
#          Series Name  Series Code    Country Name Country Code 1990 [YR1990]  \
# 0  Population, total  SP.POP.TOTL     Afghanistan          AFG      12412311
# 1  Population, total  SP.POP.TOTL         Albania          ALB       3286542
# 2  Population, total  SP.POP.TOTL         Algeria          DZA      25758872
# 3  Population, total  SP.POP.TOTL  American Samoa          ASM         47351
# 4  Population, total  SP.POP.TOTL         Andorra          AND         54508
#
#   1991 [YR1991] 1992 [YR1992] 1993 [YR1993] 1994 [YR1994] 1995 [YR1995]  ...  \
# 0      13299016      14485543      15816601      17075728      18110662  ...
# 1       3266790       3247039       3227287       3207536       3187784  ...
# 2      26400468      27028330      27635517      28213777      28757788  ...
# 3         48682         49900         51025         52099         53158  ...
# 4         56666         58882         60974         62676         63860  ...
#
#   2012 [YR2012] 2013 [YR2013] 2014 [YR2014] 2015 [YR2015] 2016 [YR2016]  \
# 0      31161378      32269592      33370804      34413603      35383028
# 1       2900401       2895092       2889104       2880703       2876101
# 2      37383899      38140135      38923688      39728020      40551398
# 3         55669         55717         55791         55806         55739
# 4         82427         80770         79213         77993         77295
#
#   2017 [YR2017] 2018 [YR2018] 2019 [YR2019] 2020 [YR2020] 2021 [YR2021]
# 0      36296111      37171922      38041757      38928341      39835428
# 1       2873457       2866376       2854191       2837849       2811666
# 2      41389174      42228415      43053054      43851043      44616626
# 3         55617         55461         55312         55197         55103
# 4         76997         77008         77146         77265         77354
#
# [5 rows x 36 columns]

# %%
# Import input dataset, add Age Group column, and clean header names
df_under5 = pd.read_csv('raw_data/causes-of-death-in-children-under-5.csv')
df_under5['Age Group'] = 'Under 5'
df_under5.columns = [col if len(col.split('-')) <= 1 else col.split('-')[1].strip() for col in df_under5.columns.values]
df_under5.head()
# Out:
#         Entity Code  Year  Invasive Non  Interpersonal violence  \
# 0  Afghanistan  AFG  1990            48                     105
# 1  Afghanistan  AFG  1991            55                     130
# 2  Afghanistan  AFG  1992            68                     155
# 3  Afghanistan  AFG  1993            78                     178
# 4  Afghanistan  AFG  1994            83                     194
#
#    Nutritional deficiencies  Acute hepatitis  Neoplasms  Measles  \
# 0                      1779              718        431     8649
# 1                      1822              741        439     8669
# 2                      2069              836        486     8539
# 3                      2427              970        549     8949
# 4                      2649             1063        589    10642
#
#    Digestive diseases  ...  Whooping cough  Diarrheal diseases  \
# 0                 477  ...            2455                3968
# 1                 495  ...            2385                4650
# 2                 554  ...            2370                5833
# 3                 630  ...            2659                7800
# 4                 681  ...            3187                7894
#
#    Fire, heat, and hot substances  Road injuries  Tuberculosis  HIV/AIDS  \
# 0                             131            802           808        10
# 1                             129            781           800        12
# 2                             137            821           863        13
# 3                             155            923           979        16
# 4                             170           1015          1064        19
#
#    Drowning  Malaria  Syphilis  Age Group
# 0       776       21       123    Under 5
# 1       748       41       132    Under 5
# 2       777       51       180    Under 5
# 3       872       24       239    Under 5
# 4       961       52       259    Under 5
#
# [5 rows x 33 columns]

# %%
# Import input dataset, add Age Group column, and clean header names
df_5to14 = pd.read_csv('raw_data/causes-of-death-in-5-14-year-olds.csv')
df_5to14['Age Group'] = '5-14'
df_5to14.columns = [col if len(col.split('-')) <= 1 else col.split('-')[1].strip() for col in df_5to14.columns.values]
df_5to14.head()
# Out:
#         Entity Code  Year  Self  Interpersonal violence  Drowning  Malaria  \
# 0  Afghanistan  AFG  1990    12                      65       290        3
# 1  Afghanistan  AFG  1991    12                      80       311        6
# 2  Afghanistan  AFG  1992    14                      88       356        8
# 3  Afghanistan  AFG  1993    15                      97       393        3
# 4  Afghanistan  AFG  1994    15                     105       410        7
#
#    Fire, heat, and hot substances  Neoplasms  Digestive diseases  ...  \
# 0                              27        278                 119  ...
# 1                              30        299                 129  ...
# 2                              34        341                 147  ...
# 3                              38        373                 162  ...
# 4                              39        385                 170  ...
#
#    Diabetes mellitus  Protein  Exposure to forces of nature  \
# 0                 11       99                             0
# 1                 12      108                           277
# 2                 14      124                           120
# 3                 15      138                            42
# 4                 16      145                            29
#
#    Environmental heat and cold exposure  Diarrheal diseases  Road injuries  \
# 0                                     2                  27            511
# 1                                     2                  30            552
# 2                                     1                  34            633
# 3                                     1                  60            695
# 4                                     1                  42            721
#
#    Tuberculosis  HIV/AIDS  Acute hepatitis  Age Group
# 0           160         0              103       5-14
# 1           170         0              112       5-14
# 2           191         0              129       5-14
# 3           205         1              143       5-14
# 4           209         1              150       5-14
#
# [5 rows x 26 columns]

# %%
# Import input dataset, add Age Group column, and clean header names
df_15to49 = pd.read_csv('raw_data/causes-of-death-in-15-49-year-olds.csv')
df_15to49['Age Group'] = '15-49'
df_15to49.columns = [col if len(col.split('-')) <= 1 else col.split('-')[1].strip() for col in df_15to49.columns.values]
df_15to49.head()
# Out:
#         Entity Code  Year  Self  Interpersonal violence  Drowning  Malaria  \
# 0  Afghanistan  AFG  1990   482                    1126       234       46
# 1  Afghanistan  AFG  1991   535                    1510       262       94
# 2  Afghanistan  AFG  1992   634                    1782       311      125
# 3  Afghanistan  AFG  1993   716                    2038       350       58
# 4  Afghanistan  AFG  1994   759                    2260       365      110
#
#    Fire, heat, and hot substances  Neoplasms  Digestive diseases  ...  \
# 0                              86       2078                 731  ...
# 1                              94       2183                 773  ...
# 2                             109       2386                 853  ...
# 3                             121       2544                 917  ...
# 4                             126       2615                 948  ...
#
#    Exposure to forces of nature  Environmental heat and cold exposure  \
# 0                             0                                    73
# 1                           543                                    52
# 2                           266                                    27
# 3                           103                                    31
# 4                            73                                    33
#
#    Diarrheal diseases  Road injuries  Tuberculosis  HIV/AIDS  \
# 0                  42           2033          1208        15
# 1                  46           2317          1289        19
# 2                  54           2814          1446        24
# 3                  77           3204          1575        28
# 4                  64           3385          1653        32
#
#    Alzheimer's disease and other dementias  Parkinson's disease  \
# 0                                        5                   10
# 1                                        5                   10
# 2                                        5                   10
# 3                                        5                   10
# 4                                        5                   11
#
#    Acute hepatitis  Age Group
# 0              553      15-49
# 1              595      15-49
# 2              671      15-49
# 3              737      15-49
# 4              776      15-49
#
# [5 rows x 30 columns]

# %%
# Import input dataset, add Age Group column, and clean header names
df_50to69 = pd.read_csv('raw_data/causes-of-death-in-50-69-year-olds.csv')
df_50to69['Age Group'] = '50-69'
df_50to69.columns = [col if len(col.split('-')) <= 1 else col.split('-')[1].strip() for col in df_50to69.columns.values]
df_50to69.head()
# Out:
#         Entity Code  Year  Self  Interpersonal violence  \
# 0  Afghanistan  AFG  1990   167                     208
# 1  Afghanistan  AFG  1991   168                     242
# 2  Afghanistan  AFG  1992   171                     235
# 3  Afghanistan  AFG  1993   176                     237
# 4  Afghanistan  AFG  1994   180                     249
#
#    Cardiovascular diseases  Drug use disorders  Nutritional deficiencies  \
# 0                    20666                  23                        49
# 1                    20840                  24                        50
# 2                    21174                  25                        52
# 3                    21699                  26                        55
# 4                    22273                  28                        58
#
#    Alcohol use disorders  Lower respiratory infections  ...  Acute hepatitis  \
# 0                     28                           932  ...             1232
# 1                     28                           941  ...             1255
# 2                     28                           956  ...             1287
# 3                     29                           979  ...             1333
# 4                     29                          1003  ...             1385
#
#    Malaria  Fire, heat, and hot substances  Neoplasms  Digestive diseases  \
# 0       19                              54       5446                1992
# 1       38                              55       5493                2012
# 2       44                              56       5577                2043
# 3       17                              57       5679                2082
# 4       33                              58       5771                2121
#
#    Cirrhosis and other chronic liver diseases  Chronic respiratory diseases  \
# 0                                        1233                          2453
# 1                                        1247                          2481
# 2                                        1268                          2526
# 3                                        1293                          2594
# 4                                        1315                          2672
#
#    Chronic kidney disease  Diabetes mellitus  Age Group
# 0                    1534               1100      50-69
# 1                    1527               1100      50-69
# 2                    1521               1107      50-69
# 3                    1529               1122      50-69
# 4                    1545               1140      50-69
#
# [5 rows x 30 columns]

# %%
# Import input dataset, add Age Group column, and clean header names
df_70 = pd.read_csv('raw_data/causes-of-death-in-70-year-olds.csv')
df_70['Age Group'] = '70'
df_70.columns = [col if len(col.split('-')) <= 1 else col.split('-')[1].strip() for col in df_70.columns.values]
df_70.head()
# Out:
#         Entity Code  Year  Self  Interpersonal violence  \
# 0  Afghanistan  AFG  1990    35                      33
# 1  Afghanistan  AFG  1991    35                      39
# 2  Afghanistan  AFG  1992    36                      38
# 3  Afghanistan  AFG  1993    37                      39
# 4  Afghanistan  AFG  1994    38                      41
#
#    Exposure to forces of nature  Drowning  \
# 0                             0        14
# 1                           101        14
# 2                            40        14
# 3                            13        15
# 4                             9        15
#
#    Environmental heat and cold exposure  Diarrheal diseases  Road injuries  \
# 0                                    20                 140            169
# 1                                    12                 142            173
# 2                                     2                 142            177
# 3                                     2                 162            182
# 4                                     2                 151            187
#
#    ...  Alzheimer's disease and other dementias  Cardiovascular diseases  \
# 0  ...                                      973                    18600
# 1  ...                                      991                    18820
# 2  ...                                     1013                    19109
# 3  ...                                     1036                    19565
# 4  ...                                     1058                    20084
#
#    Nutritional deficiencies  Drug use disorders  Alcohol use disorders  \
# 0                        21                   7                      6
# 1                        22                   8                      6
# 2                        23                   8                      6
# 3                        24                   8                      6
# 4                        25                   9                      6
#
#    Lower respiratory infections  Diabetes mellitus  Protein  Acute hepatitis  \
# 0                          1559                730       16              378
# 1                          1576                729       16              389
# 2                          1595                730       17              401
# 3                          1628                736       18              419
# 4                          1668                744       19              441
#
#    Age Group
# 0         70
# 1         70
# 2         70
# 3         70
# 4         70
#
# [5 rows x 30 columns]

# %%
# Check data types
# cause_of_death_df.dtypes

# %%
# Correct data types
# cause_of_death_df['Age Group'] = pd.Series(df_under5['Age Group'], dtype='string')
# cause_of_death_df['Entity'] = pd.Series(df_under5['Entity'], dtype='string') 
# cause_of_death_df['Code'] = pd.Series(df_under5['Code'], dtype='string')  
# column_to_move = cause_of_death_df.pop('Age Group')
# cause_of_death_df.insert(3, 'Age Group', column_to_move)

# %%
# Move Age Group column to front of dataframe

# %%
# Upload dataframe to database

db_string = f"postgresql://postgres:{db_password}@127.0.0.1:5432/Capstone_DB"
engine = create_engine(db_string)

df_under5.to_sql(name='cod_under5', con=engine, if_exists='replace')
df_5to14.to_sql(name='cod_5to14', con=engine, if_exists='replace')
df_15to49.to_sql(name='cod_15to49', con=engine, if_exists='replace')
df_50to69.to_sql(name='cod_50to69', con=engine, if_exists='replace')
df_70.to_sql(name='cod_70', con=engine, if_exists='replace')

health_data.to_sql(name='health_data', con=engine, if_exists='replace')
# cause_of_death_df.to_sql(name='cause_of_death', con=engine, if_exists='replace')
